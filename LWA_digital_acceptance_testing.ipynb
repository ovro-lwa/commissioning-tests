# %% [markdown]
# # Digital acceptance testing
#
# Goal is to make it easy to modify f-eng configuration while recording data.
#
# 1. Write MS file
# - set all inputs to zeros
# - set pol a inputs to adc, then pol b to adc
# - set eq coeffs to zero for first ten channels on first snap, then iterate through all snaps
#
# 2. Write beamformed data
# - set inputs to zeros
# - set pol a inputs to adc, then pol b to adc
# - set eq coeffs to zero for first ten channels on first snap, then iterate through all snaps
# 3. Read autos from MS file
# - confirm order of zeros, adc on pol on sequence, channel off sequence, and antennas off sequence
# 4. Read beamformed data
# - confirm order of zeros, adc on pol order, channel off order by channel

# %% [markdown]
# ### Setup

# %%
# %matplotlib inline

# %%
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time
from matplotlib import animation
from matplotlib import pyplot as plt
from IPython.display import Image

from mnc import control
from lwa_f import snap2_fengine, snap2_feng_etcd_client
from lwa_antpos import mapping
import casacore.tables
from retry import retry
# Out:
# Read antpos from etcd

# %%
from bokeh.layouts import column, row
from bokeh.models import ColumnDataSource, DataRange1d, Select
from bokeh.palettes import Viridis
from bokeh.plotting import figure
from bokeh.io import show, output_notebook

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
snap2names = [f'snap{i:02}' for i in range(1, 12)]

def set_input(mode='use_zero', stream=None, pol=None, names=snap2names):
    """ Set the input block method
    mode can be "use_zero", "use_adc", "use_noise", "zero_coeffs",
    "reset_coeffs", "get_status".
    """

    if isinstance(names, str):
        names = [names]

    for name in names:
        f = snap2_fengine.Snap2Fengine(name)
        num = int(name.lstrip('snap'))

        if (pol is None) or isinstance(stream, int):
            print(f"Set stream: {stream}")
            run(f, stream, mode=mode)
        elif (stream is None) and (pol is not None):
            antpols = []
            if pol == 'a':
                inps = list(range(0,64,2))
            elif pol == 'b':
                inps = list(range(1,64,2))
            for inp in inps:
                antpols.append(mapping.snap2_to_antpol(num, inp))
                run(f, inp, mode=mode)
            print(f"Set antpols {antpols}")

@retry(RuntimeError, tries=2)
def run(f, stream, mode='use_zero', zerochans=range(0, 5)):
    if mode == 'use_zero':
        f.input.use_zero(stream)
    elif mode == 'use_adc':
        f.input.use_adc(stream)
    elif mode == 'use_noise':
        f.input.use_noise(stream)
    elif mode == 'get_status':
        print('input status:')
        f.input.get_status()
        print('eqtvg status:')
        f.eqtvg.get_status()
    elif mode == 'reset_coeffs':
        f.eq.initialize(read_only=False)
    elif mode == 'zero_coeffs':
        for i in range(64):
            coeffs, scalefactor = f.eq.get_coeffs(i)
            # [1] is scale factor (coeff binary point), coeff = 9600/2**scalefactor?
            coeffs2 = coeffs >> zeropoint
            coeffs2[:5] = 0
            f.eq.set_coeffs(i, coeffs=coeffs2)
    else:
        print(f'mode {mode} not recognized')
# or
#        f.eqtvg.tvg_enable()
#        f.eqtvg.write_stream_tvg()
#        f.eqtvg.write_const_per_stream()
#        f.eqtvg.write_freq_ramp()

def plot_autospecs(names=snap2names, ret=False, bokeh=True):
    """ plots auto correlations for sets of snap2names.
    Can optionally return array with ret=True.
    """

    if isinstance(names, str):
        names = [names]

    autospecs = []
    for name in names:
        f = snap2_fengine.Snap2Fengine(name)
        for i in range(64):
            spec = f.corr.get_new_corr(i, i).real  # 8-channel average, normalized by accumulated time/chans
            autospecs.append(spec)
    autospecs = np.vstack(autospecs)

    if bokeh:
        TOOLTIPS = [("x", "$x"), ("y", "$y"), ("value", "@image")]
        plot = figure(plot_width=800, plot_height=400, tooltips=TOOLTIPS)
        _ = plot.image(image=[autospecs], x=0, y=0, dw=512, dh=len(autospecs), palette=Viridis[4])
        plot.xaxis.axis_label = 'Channel (8-chan avg)'
        plot.yaxis.axis_label = 'Input (64 per snap, stacked)'
        show(plot)
    else:
        fig, (ax0) = plt.subplots(1, 1, figsize=(12,12))
        ax0.imshow(autospecs, origin='lower', interpolation='nearest')

    if ret:
        return autospecs

# %%
con = control.Controller("/home/pipeline/proj/lwa-shell/mnc_python/config/lwa_config_calim.yaml")
# Out:
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654080192', 'val': {'status': 'normal', 'response': 1589222, 'timestamp': 1667495654.0867126}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654089802', 'val': {'status': 'normal', 'response': 1589223, 'timestamp': 1667495654.095255}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654098825', 'val': {'status': 'normal', 'response': 1589224, 'timestamp': 1667495654.1043694}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654107521', 'val': {'status': 'normal', 'response': 1589225, 'timestamp': 1667495654.1124053}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654114641', 'val': {'status': 'normal', 'response': 15835, 'timestamp': 1667495654.1191223}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654122642', 'val': {'status': 'normal', 'response': 15836, 'timestamp': 1667495654.132573}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654135568', 'val': {'status': 'normal', 'response': 15837, 'timestamp': 1667495654.1411695}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654142657', 'val': {'status': 'normal', 'response': 15838, 'timestamp': 1667495654.1479607}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654151818', 'val': {'status': 'normal', 'response': 22986, 'timestamp': 1667495654.156978}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654160204', 'val': {'status': 'normal', 'response': 22987, 'timestamp': 1667495654.1656377}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654168137', 'val': {'status': 'normal', 'response': 22988, 'timestamp': 1667495654.1819458}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654184992', 'val': {'status': 'normal', 'response': 22989, 'timestamp': 1667495654.1900723}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654219673', 'val': {'status': 'normal', 'response': 30788, 'timestamp': 1667495654.2256806}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654227996', 'val': {'status': 'normal', 'response': 30789, 'timestamp': 1667495654.2392569}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654240693', 'val': {'status': 'normal', 'response': 30790, 'timestamp': 1667495654.245057}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654247659', 'val': {'status': 'normal', 'response': 30791, 'timestamp': 1667495654.2519782}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654254171', 'val': {'status': 'normal', 'response': 30441, 'timestamp': 1667495654.258181}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654259545', 'val': {'status': 'normal', 'response': 30442, 'timestamp': 1667495654.2636719}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654266197', 'val': {'status': 'normal', 'response': 30443, 'timestamp': 1667495654.2702951}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654272648', 'val': {'status': 'normal', 'response': 30444, 'timestamp': 1667495654.2769709}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654278267', 'val': {'status': 'normal', 'response': 26166, 'timestamp': 1667495654.2831588}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654283832', 'val': {'status': 'normal', 'response': 26167, 'timestamp': 1667495654.2887836}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654290481', 'val': {'status': 'normal', 'response': 26168, 'timestamp': 1667495654.2952452}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654296110', 'val': {'status': 'normal', 'response': 26169, 'timestamp': 1667495654.3009298}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654301806', 'val': {'status': 'normal', 'response': 3949, 'timestamp': 1667495654.3065891}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654308246', 'val': {'status': 'normal', 'response': 3950, 'timestamp': 1667495654.3137026}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654316249', 'val': {'status': 'normal', 'response': 3951, 'timestamp': 1667495654.3200593}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654322579', 'val': {'status': 'normal', 'response': 3952, 'timestamp': 1667495654.3265033}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654329232', 'val': {'status': 'normal', 'response': 5992, 'timestamp': 1667495654.3334248}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654335773', 'val': {'status': 'normal', 'response': 5993, 'timestamp': 1667495654.342784}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654344217', 'val': {'status': 'normal', 'response': 5994, 'timestamp': 1667495654.3481598}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1667495654349684', 'val': {'status': 'normal', 'response': 5995, 'timestamp': 1667495654.3537102}}
# Loaded configuration for 8 x-engine host(s) running 4 pipeline(s) each
# Supported modes are: slow,beam1,beam2,beam3,beam4,beam5,beam6,beam7,beam8
# etcd server being used is: etcdv3service

# %%
con.start_fengine()
# Out:
# 2022-11-03 17:14:22,061 - lwa_f.blocks.block:snap01 - INFO - adc - Detected FMC ADC board on port 0
# 2022-11-03 17:14:22,695 - lwa_f.blocks.block:snap01 - INFO - adc - Detected FMC ADC board on port 1
# snap01 is already connected.
# 2022-11-03 17:14:24,040 - lwa_f.blocks.block:snap02 - INFO - adc - Detected FMC ADC board on port 0
# 2022-11-03 17:14:24,871 - lwa_f.blocks.block:snap02 - INFO - adc - Detected FMC ADC board on port 1
# snap02 is already connected.
# 2022-11-03 17:14:26,089 - lwa_f.blocks.block:snap03 - INFO - adc - Detected FMC ADC board on port 0
# 2022-11-03 17:14:26,812 - lwa_f.blocks.block:snap03 - INFO - adc - Detected FMC ADC board on port 1
# snap03 is already connected.
# 2022-11-03 17:14:28,238 - lwa_f.blocks.block:snap04 - INFO - adc - Detected FMC ADC board on port 0
# 2022-11-03 17:14:28,864 - lwa_f.blocks.block:snap04 - INFO - adc - Detected FMC ADC board on port 1
# snap04 is already connected.
# 2022-11-03 17:14:33,075 - lwa_f.blocks.block:snap05 - INFO - adc - Detected FMC ADC board on port 0
# 2022-11-03 17:14:33,793 - lwa_f.blocks.block:snap05 - INFO - adc - Detected FMC ADC board on port 1
# snap05 is already connected.
# 2022-11-03 17:14:34,908 - lwa_f.blocks.block:snap06 - INFO - adc - Detected FMC ADC board on port 0
# 2022-11-03 17:14:35,546 - lwa_f.blocks.block:snap06 - INFO - adc - Detected FMC ADC board on port 1
# snap06 is already connected.
# 2022-11-03 17:14:36,665 - lwa_f.blocks.block:snap07 - INFO - adc - Detected FMC ADC board on port 0
# 2022-11-03 17:14:37,297 - lwa_f.blocks.block:snap07 - INFO - adc - Detected FMC ADC board on port 1
# snap07 is already connected.
# 2022-11-03 17:14:38,633 - lwa_f.blocks.block:snap08 - INFO - adc - Detected FMC ADC board on port 0
# 2022-11-03 17:14:39,590 - lwa_f.blocks.block:snap08 - INFO - adc - Detected FMC ADC board on port 1
# snap08 is already connected.
# 2022-11-03 17:14:40,911 - lwa_f.blocks.block:snap09 - INFO - adc - Detected FMC ADC board on port 0
# 2022-11-03 17:14:41,643 - lwa_f.blocks.block:snap09 - INFO - adc - Detected FMC ADC board on port 1
# snap09 is already connected.
# 2022-11-03 17:14:45,873 - lwa_f.blocks.block:snap10 - INFO - adc - Detected FMC ADC board on port 0
# 2022-11-03 17:14:46,707 - lwa_f.blocks.block:snap10 - INFO - adc - Detected FMC ADC board on port 1
# snap10 is already connected.
# 2022-11-03 17:14:47,920 - lwa_f.blocks.block:snap11 - INFO - adc - Detected FMC ADC board on port 0
# 2022-11-03 17:14:48,535 - lwa_f.blocks.block:snap11 - INFO - adc - Detected FMC ADC board on port 1
# snap11 is already connected.

# %%
con.stop_xengine()
con.start_xengine()
# Out:
# 2022-11-03 17:45:30 [INFO    ] Pipelines all appear to be ready after 17.4 seconds
# INFO:Pipelines all appear to be ready after 17.4 seconds
# INFO:pipelines up? True
# pipelines up? True
# Configuring x-engine for slow visibilities
# 2022-11-03 17:45:30 [INFO    ] Setting max data output rate per pipeline to 625.0 Mbit/s
# INFO:Setting max data output rate per pipeline to 625.0 Mbit/s
# 2022-11-03 17:45:30 [INFO    ] Setting pipeline lxdlwagpu01:0 data destination to 10.41.0.76:10001
# INFO:Setting pipeline lxdlwagpu01:0 data destination to 10.41.0.76:10001
# 2022-11-03 17:45:30 [INFO    ] Setting pipeline lxdlwagpu01:1 data destination to 10.41.0.76:10001
# INFO:Setting pipeline lxdlwagpu01:1 data destination to 10.41.0.76:10001
# 2022-11-03 17:45:30 [INFO    ] Setting pipeline lxdlwagpu01:2 data destination to 10.41.0.76:10002
# INFO:Setting pipeline lxdlwagpu01:2 data destination to 10.41.0.76:10002
# 2022-11-03 17:45:30 [INFO    ] Setting pipeline lxdlwagpu01:3 data destination to 10.41.0.76:10002
# INFO:Setting pipeline lxdlwagpu01:3 data destination to 10.41.0.76:10002
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu02:0 data destination to 10.41.0.77:10001
# INFO:Setting pipeline lxdlwagpu02:0 data destination to 10.41.0.77:10001
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu02:1 data destination to 10.41.0.77:10001
# INFO:Setting pipeline lxdlwagpu02:1 data destination to 10.41.0.77:10001
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu02:2 data destination to 10.41.0.77:10002
# INFO:Setting pipeline lxdlwagpu02:2 data destination to 10.41.0.77:10002
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu02:3 data destination to 10.41.0.77:10002
# INFO:Setting pipeline lxdlwagpu02:3 data destination to 10.41.0.77:10002
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu03:0 data destination to 10.41.0.78:10001
# INFO:Setting pipeline lxdlwagpu03:0 data destination to 10.41.0.78:10001
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu03:1 data destination to 10.41.0.78:10001
# INFO:Setting pipeline lxdlwagpu03:1 data destination to 10.41.0.78:10001
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu03:2 data destination to 10.41.0.78:10002
# INFO:Setting pipeline lxdlwagpu03:2 data destination to 10.41.0.78:10002
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu03:3 data destination to 10.41.0.78:10002
# INFO:Setting pipeline lxdlwagpu03:3 data destination to 10.41.0.78:10002
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu04:0 data destination to 10.41.0.79:10001
# INFO:Setting pipeline lxdlwagpu04:0 data destination to 10.41.0.79:10001
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu04:1 data destination to 10.41.0.79:10001
# INFO:Setting pipeline lxdlwagpu04:1 data destination to 10.41.0.79:10001
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu04:2 data destination to 10.41.0.79:10002
# INFO:Setting pipeline lxdlwagpu04:2 data destination to 10.41.0.79:10002
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu04:3 data destination to 10.41.0.79:10002
# INFO:Setting pipeline lxdlwagpu04:3 data destination to 10.41.0.79:10002
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu05:0 data destination to 10.41.0.80:10001
# INFO:Setting pipeline lxdlwagpu05:0 data destination to 10.41.0.80:10001
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu05:1 data destination to 10.41.0.80:10001
# INFO:Setting pipeline lxdlwagpu05:1 data destination to 10.41.0.80:10001
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu05:2 data destination to 10.41.0.80:10002
# INFO:Setting pipeline lxdlwagpu05:2 data destination to 10.41.0.80:10002
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu05:3 data destination to 10.41.0.80:10002
# INFO:Setting pipeline lxdlwagpu05:3 data destination to 10.41.0.80:10002
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu06:0 data destination to 10.41.0.81:10001
# INFO:Setting pipeline lxdlwagpu06:0 data destination to 10.41.0.81:10001
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu06:1 data destination to 10.41.0.81:10001
# INFO:Setting pipeline lxdlwagpu06:1 data destination to 10.41.0.81:10001
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu06:2 data destination to 10.41.0.81:10002
# INFO:Setting pipeline lxdlwagpu06:2 data destination to 10.41.0.81:10002
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu06:3 data destination to 10.41.0.81:10002
# INFO:Setting pipeline lxdlwagpu06:3 data destination to 10.41.0.81:10002
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu07:0 data destination to 10.41.0.82:10001
# INFO:Setting pipeline lxdlwagpu07:0 data destination to 10.41.0.82:10001
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu07:1 data destination to 10.41.0.82:10001
# INFO:Setting pipeline lxdlwagpu07:1 data destination to 10.41.0.82:10001
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu07:2 data destination to 10.41.0.82:10002
# INFO:Setting pipeline lxdlwagpu07:2 data destination to 10.41.0.82:10002
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu07:3 data destination to 10.41.0.82:10002
# INFO:Setting pipeline lxdlwagpu07:3 data destination to 10.41.0.82:10002
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu08:0 data destination to 10.41.0.83:10001
# INFO:Setting pipeline lxdlwagpu08:0 data destination to 10.41.0.83:10001
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu08:1 data destination to 10.41.0.83:10001
# INFO:Setting pipeline lxdlwagpu08:1 data destination to 10.41.0.83:10001
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu08:2 data destination to 10.41.0.83:10002
# INFO:Setting pipeline lxdlwagpu08:2 data destination to 10.41.0.83:10002
# 2022-11-03 17:45:31 [INFO    ] Setting pipeline lxdlwagpu08:3 data destination to 10.41.0.83:10002
# INFO:Setting pipeline lxdlwagpu08:3 data destination to 10.41.0.83:10002
# 2022-11-03 17:45:31 [INFO    ] Arming correlator core
# INFO:Arming correlator core
# 2022-11-03 17:45:33 [INFO    ] All pipelines in 'waiting' state as expected
# INFO:All pipelines in 'waiting' state as expected
# 2022-11-03 17:45:33 [INFO    ] Waiting 10 seconds for trigger
# INFO:Waiting 10 seconds for trigger
# 2022-11-03 17:45:43 [INFO    ] All pipelines in 'running' state as expected
# INFO:All pipelines in 'running' state as expected
# 2022-11-03 17:45:43 [INFO    ] Arming correlator accumulator core
# INFO:Arming correlator accumulator core
# 2022-11-03 17:45:44 [INFO    ] All pipelines in 'waiting' state as expected
# INFO:All pipelines in 'waiting' state as expected
# 2022-11-03 17:45:44 [INFO    ] Waiting 10 seconds for trigger
# INFO:Waiting 10 seconds for trigger
# 2022-11-03 17:45:54 [INFO    ] All pipelines in 'running' state as expected
# INFO:All pipelines in 'running' state as expected
# Not configuring x-engine for fast visibilities
# Start power beams with "start_xengine_bf" method"

# %%
con.status_dr(['drvs', 'dr1', 'dr2'])
# Out:
# ['14 recording; 0 idle; 2 timed out',
#  'WARNING: drvs not fully operational: 3 sub-bands have not updated in 120 s: drvs7702,drvs8101,drvs8102',
#  'idle',
#  'idle']

# %%
con.start_dr(recorders=['drvs', 'dr1', 'dr2'], duration=30)
# Out:
# Starting recorders: ['drvs', 'dr1', 'dr2']
# WARNING: recording on drvs failed: {'drvs7601': {'sequence_id': 'a2fce3065b9f11edb2283cecef5ef4c6', 'timestamp': 1667497671.0830941, 'status': 'error', 'response': 'Failed to schedule recording start: Operation starts during a previously scheduled operation'}, 'drvs7602': {'sequence_id': 'a2fe99a85b9f11edb2283cecef5ef4c6', 'timestamp': 1667497671.09226, 'status': 'error', 'response': 'Failed to schedule recording start: Operation starts during a previously scheduled operation'}, 'drvs7701': {'sequence_id': 'a2ffed9e5b9f11edb2283cecef5ef4c6', 'timestamp': 1667497671.1020305, 'status': 'error', 'response': 'Failed to schedule recording start: Operation starts during a previously scheduled operation'}, 'drvs7702': {'sequence_id': 'a30177045b9f11edb2283cecef5ef4c6', 'timestamp': 1667497671.1109712, 'status': 'error', 'response': 'Failed to schedule recording start: Operation starts during a previously scheduled operation'}, 'drvs7801': {'sequence_id': 'a302f1e25b9f11edb2283cecef5ef4c6', 'timestamp': 1667497671.118825, 'status': 'error', 'response': 'Failed to schedule recording start: Operation starts during a previously scheduled operation'}, 'drvs7802': {'sequence_id': 'a30453a25b9f11edb2283cecef5ef4c6', 'timestamp': 1667497671.1267133, 'status': 'error', 'response': 'Failed to schedule recording start: Operation starts during a previously scheduled operation'}, 'drvs7901': {'sequence_id': 'a30558f65b9f11edb2283cecef5ef4c6', 'timestamp': 1667497671.135769, 'status': 'error', 'response': 'Failed to schedule recording start: Operation starts during a previously scheduled operation'}, 'drvs7902': {'sequence_id': 'a306a53a5b9f11edb2283cecef5ef4c6', 'timestamp': 1667497671.1439483, 'status': 'error', 'response': 'Failed to schedule recording start: Operation starts during a previously scheduled operation'}, 'drvs8001': {'sequence_id': 'a308c1305b9f11edb2283cecef5ef4c6', 'timestamp': 1667497671.1578667, 'status': 'error', 'response': 'Failed to schedule recording start: Operation starts during a previously scheduled operation'}, 'drvs8002': {'sequence_id': 'a30a0f905b9f11edb2283cecef5ef4c6', 'timestamp': 1667497671.1659284, 'status': 'error', 'response': 'Failed to schedule recording start: Operation starts during a previously scheduled operation'}, 'drvs8101': 'a30b5df05b9f11edb2283cecef5ef4c6', 'drvs8102': 'a33214725b9f11edb2283cecef5ef4c6', 'drvs8201': {'sequence_id': 'a358db2a5b9f11edb2283cecef5ef4c6', 'timestamp': 1667497671.6821923, 'status': 'error', 'response': 'Failed to schedule recording start: Operation starts during a previously scheduled operation'}, 'drvs8202': {'sequence_id': 'a35ac4e45b9f11edb2283cecef5ef4c6', 'timestamp': 1667497671.694213, 'status': 'error', 'response': 'Failed to schedule recording start: Operation starts during a previously scheduled operation'}, 'drvs8301': {'sequence_id': 'a35ba7e25b9f11edb2283cecef5ef4c6', 'timestamp': 1667497671.700259, 'status': 'error', 'response': 'Failed to schedule recording start: Operation starts during a previously scheduled operation'}, 'drvs8302': {'sequence_id': 'a35cbd4e5b9f11edb2283cecef5ef4c6', 'timestamp': 1667497671.708342, 'status': 'error', 'response': 'Failed to schedule recording start: Operation starts during a previously scheduled operation'}}
# recording on dr1 for 0.030 s to file /data01/beam01/059886_174806723624a35ee27
# recording on dr2 for 0.030 s to file /data01/beam02/059886_174806736674a360eb3

# %%
con.start_xengine_bf(num=1, calibrate=False)
# Out:
# Coordinates not fully specified. Pointing at zenith.
# No calibration will be applied
# /home/pipeline/.conda/envs/development/lib/python3.6/site-packages/mnc/xengine_beamformer_control.py:556: UserWarning: No calibration data found in '/pathshouldnotexist'
#   warnings.warn(f"No calibration data found in '{cal_directory}'")
# /home/pipeline/.conda/envs/development/lib/python3.6/site-packages/mnc/xengine_beamformer_control.py:351: UserWarning: Calibration is not set, your results may be suspect
#   warnings.warn("Calibration is not set, your results may be suspect")
# Not tracking for azel input

# %%
con.start_xengine_bf(num=2, calibrate=False)
# Out:
# Coordinates not fully specified. Pointing at zenith.
# No calibration will be applied
# Not tracking for azel input

# %%
con.stop_dr()
# Out:
# WARNING: stopping recording on drvs failed: {'drvs7601': {'sequence_id': 'cde1cdf65ba011edb2283cecef5ef4c6', 'timestamp': 1667498172.5440927, 'status': 'error', 'response': 'Failed to find operation active at the specified stop time'}, 'drvs7602': {'sequence_id': 'cde359be5ba011edb2283cecef5ef4c6', 'timestamp': 1667498172.5523481, 'status': 'error', 'response': 'Failed to find operation active at the specified stop time'}, 'drvs7701': {'sequence_id': 'cde48c3a5ba011edb2283cecef5ef4c6', 'timestamp': 1667498172.5597656, 'status': 'error', 'response': 'Failed to find operation active at the specified stop time'}, 'drvs7702': {'sequence_id': 'cde597885ba011edb2283cecef5ef4c6', 'timestamp': 1667498172.566258, 'status': 'error', 'response': 'Failed to find operation active at the specified stop time'}, 'drvs7801': {'sequence_id': 'cde6a3625ba011edb2283cecef5ef4c6', 'timestamp': 1667498172.5720878, 'status': 'error', 'response': 'Failed to find operation active at the specified stop time'}, 'drvs7802': {'sequence_id': 'cde7e29a5ba011edb2283cecef5ef4c6', 'timestamp': 1667498172.5790055, 'status': 'error', 'response': 'Failed to find operation active at the specified stop time'}, 'drvs7901': {'sequence_id': 'cde8d0ce5ba011edb2283cecef5ef4c6', 'timestamp': 1667498172.5879395, 'status': 'error', 'response': 'Failed to find operation active at the specified stop time'}, 'drvs7902': {'sequence_id': 'cdea279e5ba011edb2283cecef5ef4c6', 'timestamp': 1667498172.595412, 'status': 'error', 'response': 'Failed to find operation active at the specified stop time'}, 'drvs8001': {'sequence_id': 'cdeb3d325ba011edb2283cecef5ef4c6', 'timestamp': 1667498172.6017125, 'status': 'error', 'response': 'Failed to find operation active at the specified stop time'}, 'drvs8002': {'sequence_id': 'cdec31e25ba011edb2283cecef5ef4c6', 'timestamp': 1667498172.61065, 'status': 'error', 'response': 'Failed to find operation active at the specified stop time'}, 'drvs8101': 'cded90b45ba011edb2283cecef5ef4c6', 'drvs8102': 'ce1444665ba011edb2283cecef5ef4c6', 'drvs8201': {'sequence_id': 'ce3b845e5ba011edb2283cecef5ef4c6', 'timestamp': 1667498173.1304169, 'status': 'error', 'response': 'Failed to find operation active at the specified stop time'}, 'drvs8202': {'sequence_id': 'ce3d07525ba011edb2283cecef5ef4c6', 'timestamp': 1667498173.1443326, 'status': 'error', 'response': 'Failed to find operation active at the specified stop time'}, 'drvs8301': {'sequence_id': 'ce3f323e5ba011edb2283cecef5ef4c6', 'timestamp': 1667498173.1543996, 'status': 'error', 'response': 'Failed to find operation active at the specified stop time'}, 'drvs8302': {'sequence_id': 'ce4095a25ba011edb2283cecef5ef4c6', 'timestamp': 1667498173.1631627, 'status': 'error', 'response': 'Failed to find operation active at the specified stop time'}}

# %% [markdown]
# ### Visualize initial state

# %%
set_input(mode='use_adc')

# %%
autospecs = plot_autospecs(ret=True)

# %% [markdown]
# ### Observing sequence

# %%
tblock = 3*10  # seconds

set_input(mode='use_zero')
time.sleep(tblock)
set_input(mode='use_adc', pol='a')
time.sleep(tblock)
set_input(mode='use_adc', pol='b')
time.sleep(tblock)
#for name in snap2names:
#    set_input(mode='zero_coeffs', names=name) # zeros some channels
#    time.sleep(tblock)
set_input(mode='reset_coeffs')
time.sleep(tblock)
set_input(mode='use_zero')
time.sleep(tblock)
set_input(mode='use_adc')
time.sleep(tblock)
# Out:
# 2022-06-01 11:32:33,601 - lwa_f.blocks.block:snap01 - WARNING -  - hostname (10.40.0.157) couldn't be turned into integer serial
# 2022-06-01 11:32:33,810 - lwa_f.blocks.block:snap01 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:32:34,023 - lwa_f.blocks.block:snap01 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:32:34,511 - lwa_f.blocks.block:snap02 - WARNING -  - hostname (10.40.0.132) couldn't be turned into integer serial
# 2022-06-01 11:32:34,806 - lwa_f.blocks.block:snap02 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:32:35,085 - lwa_f.blocks.block:snap02 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:32:35,615 - lwa_f.blocks.block:snap03 - WARNING -  - hostname (10.40.0.136) couldn't be turned into integer serial
# 2022-06-01 11:32:35,849 - lwa_f.blocks.block:snap03 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:32:36,055 - lwa_f.blocks.block:snap03 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:32:36,549 - lwa_f.blocks.block:snap04 - WARNING -  - hostname (10.40.0.134) couldn't be turned into integer serial
# 2022-06-01 11:32:36,825 - lwa_f.blocks.block:snap04 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:32:37,104 - lwa_f.blocks.block:snap04 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:32:37,601 - lwa_f.blocks.block:snap05 - WARNING -  - hostname (10.40.0.128) couldn't be turned into integer serial
# 2022-06-01 11:32:37,816 - lwa_f.blocks.block:snap05 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:32:38,043 - lwa_f.blocks.block:snap05 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:32:38,520 - lwa_f.blocks.block:snap06 - WARNING -  - hostname (10.40.0.131) couldn't be turned into integer serial
# 2022-06-01 11:32:38,741 - lwa_f.blocks.block:snap06 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:32
- lwa_f.blocks.block:snap06 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:34:44,676 - lwa_f.blocks.block:snap07 - WARNING -  - hostname (10.40.0.129) couldn't be turned into integer serial
# 2022-06-01 11:34:44,899 - lwa_f.blocks.block:snap07 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:34:45,118 - lwa_f.blocks.block:snap07 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:34:45,764 - lwa_f.blocks.block:snap08 - WARNING -  - hostname (10.40.0.188) couldn't be turned into integer serial
# 2022-06-01 11:34:45,979 - lwa_f.blocks.block:snap08 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:34:46,200 - lwa_f.blocks.block:snap08 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:34:46,869 - lwa_f.blocks.block:snap09 - WARNING -  - hostname (10.40.0.124) couldn't be turned into integer serial
# 2022-06-01 11:34:47,149 - lwa_f.blocks.block:snap09 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:34:47,410 - lwa_f.blocks.block:snap09 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:34:48,096 - lwa_f.blocks.block:snap10 - WARNING -  - hostname (10.40.0.125) couldn't be turned into integer serial
# 2022-06-01 11:34:48,336 - lwa_f.blocks.block:snap10 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:34:48,578 - lwa_f.blocks.block:snap10 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:34:49,242 - lwa_f.blocks.block:snap11 - WARNING -  - hostname (10.40.0.126) couldn't be turned into integer serial
# 2022-06-01 11:34:49,475 - lwa_f.blocks.block:snap11 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:34:49,695 - lwa_f.blocks.block:snap11 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:35:20,322 - lwa_f.blocks.block:snap01 - WARNING -  - hostname (10.40.0.157) couldn't be turned into integer serial
# 2022-06-01 11:35:20,554 - lwa_f.blocks.block:snap01 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:35:20,777 - lwa_f.blocks.block:snap01 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:35:21,238 - lwa_f.blocks.block:snap02 - WARNING -  - hostname (10.40.0.132) couldn't be turned into integer serial
# 2022-06-01 11:35:22,592 - lwa_f.blocks.block:snap02 - ERROR - adc - Failed to check ADC control register on fmc 0
# 2022-06-01 11:35:22,796 - lwa_f.blocks.block:snap02 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:35:23,984 - lwa_f.blocks.block:snap03 - WARNING -  - hostname (10.40.0.136) couldn't be turned into integer serial
# 2022-06-01 11:35:24,204 - lwa_f.blocks.block:snap03 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:35:24,415 - lwa_f.blocks.block:snap03 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:35:24,907 - lwa_f.blocks.block:snap04 - WARNING -  - hostname (10.40.0.134) couldn't be turned into integer serial
# 2022-06-01 11:35:25,181 - lwa_f.blocks.block:snap04 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:35:25,466 - lwa_f.blocks.block:snap04 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:35:26,023 - lwa_f.blocks.block:snap05 - WARNING -  - hostname (10.40.0.128) couldn't be turned into integer serial
# 2022-06-01 11:35:26,300 - lwa_f.blocks.block:snap05 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:35:26,586 - lwa_f.blocks.block:snap05 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:35:27,088 - lwa_f.blocks.block:snap06 - WARNING -  - hostname (10.40.0.131) couldn't be turned into integer serial
# 2022-06-01 11:35:27,306 - lwa_f.blocks.block:snap06 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:35:27,586 - lwa_f.blocks.block:snap06 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:35:28,111 - lwa_f.blocks.block:snap07 - WARNING -  - hostname (10.40.0.129) couldn't be turned into integer serial
# 2022-06-01 11:35:28,371 - lwa_f.blocks.block:snap07 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:35:28,598 - lwa_f.blocks.block:snap07 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:35:29,065 - lwa_f.blocks.block:snap08 - WARNING -  - hostname (10.40.0.188) couldn't be turned into integer serial
# 2022-06-01 11:35:29,286 - lwa_f.blocks.block:snap08 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:35:29,503 - lwa_f.blocks.block:snap08 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:35:29,967 - lwa_f.blocks.block:snap09 - WARNING -  - hostname (10.40.0.124) couldn't be turned into integer serial
# 2022-06-01 11:35:30,224 - lwa_f.blocks.block:snap09 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:35:30,478 - lwa_f.blocks.block:snap09 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:35:30,955 - lwa_f.blocks.block:snap10 - WARNING -  - hostname (10.40.0.125) couldn't be turned into integer serial
# 2022-06-01 11:35:31,165 - lwa_f.blocks.block:snap10 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:35:31,375 - lwa_f.blocks.block:snap10 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:35:31,828 - lwa_f.blocks.block:snap11 - WARNING -  - hostname (10.40.0.126) couldn't be turned into integer serial
# 2022-06-01 11:35:32,341 - lwa_f.blocks.block:snap11 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:35:32,545 - lwa_f.blocks.block:snap11 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:36:03,022 - lwa_f.blocks.block:snap01 - WARNING -  - hostname (10.40.0.157) couldn't be turned into integer serial
# 2022-06-01 11:36:03,226 - lwa_f.blocks.block:snap01 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:36:03,431 - lwa_f.blocks.block:snap01 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:36:03,902 - lwa_f.blocks.block:snap02 - WARNING -  - hostname (10.40.0.132) couldn't be turned into integer serial
# 2022-06-01 11:36:04,191 - lwa_f.blocks.block:snap02 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:36:04,472 - lwa_f.blocks.block:snap02 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:36:04,996 - lwa_f.blocks.block:snap03 - WARNING -  - hostname (10.40.0.136) couldn't be turned into integer serial
# 2022-06-01 11:36:05,213 - lwa_f.blocks.block:snap03 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:36:05,425 - lwa_f.blocks.block:snap03 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:36:05,892 - lwa_f.blocks.block:snap04 - WARNING -  - hostname (10.40.0.134) couldn't be turned into integer serial
# 2022-06-01 11:36:06,106 - lwa_f.blocks.block:snap04 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:36:06,342 - lwa_f.blocks.block:snap04 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:36:07,200 - lwa_f.blocks.block:snap05 - WARNING -  - hostname (10.40.0.128) couldn't be turned into integer serial
# 2022-06-01 11:36:07,476 - lwa_f.blocks.block:snap05 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:36:07,755 - lwa_f.blocks.block:snap05 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:36:08,261 - lwa_f.blocks.block:snap06 - WARNING -  - hostname (10.40.0.131) couldn't be turned into integer serial
# 2022-06-01 11:36:09,023 - lwa_f.blocks.block:snap06 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:36:09,871 - lwa_f.blocks.block:snap06 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:36:10,362 - lwa_f.blocks.block:snap07 - WARNING -  - hostname (10.40.0.129) couldn't be turned into integer serial
# 2022-06-01 11:36:10,626 - lwa_f.blocks.block:snap07 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:36:10,885 - lwa_f.blocks.block:snap07 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:36:11,363 - lwa_f.blocks.block:snap08 - WARNING -  - hostname (10.40.0.188) couldn't be turned into integer serial
# 2022-06-01 11:36:11,573 - lwa_f.blocks.block:snap08 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:36:11,983 - lwa_f.blocks.block:snap08 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:36:12,426 - lwa_f.blocks.block:snap09 - WARNING -  - hostname (10.40.0.124) couldn't be turned into integer serial
# 2022-06-01 11:36:12,665 - lwa_f.blocks.block:snap09 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:36:12,905 - lwa_f.blocks.block:snap09 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:36:13,368 - lwa_f.blocks.block:snap10 - WARNING -  - hostname (10.40.0.125) couldn't be turned into integer serial
# 2022-06-01 11:36:13,574 - lwa_f.blocks.block:snap10 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:36:13,779 - lwa_f.blocks.block:snap10 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None
# 2022-06-01 11:36:14,233 - lwa_f.blocks.block:snap11 - WARNING -  - hostname (10.40.0.126) couldn't be turned into integer serial
# 2022-06-01 11:36:14,445 - lwa_f.blocks.block:snap11 - INFO - adc - Detected FMC ADC board on port 0
# 2022-06-01 11:36:14,656 - lwa_f.blocks.block:snap11 - INFO - adc - Detected FMC ADC board on port 1
# Set stream: None

# %%
con.stop_dr()
con.stop_xengine()
# Out:
# Found 16 slow recorders: drvs2501 drvs2502 drvs2503 drvs2504 drvs2505 drvs2506 drvs2507 drvs2508 drvs7301 drvs7302 drvs7303 drvs7304 drvs7305 drvs7306 drvs7307 drvs7308
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108776699602', 'val': {'status': 'normal', 'response': 9577, 'timestamp': 1654108776.7068913}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108776715841', 'val': {'status': 'normal', 'response': 9579, 'timestamp': 1654108776.723918}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108776727596', 'val': {'status': 'normal', 'response': 9580, 'timestamp': 1654108776.7367353}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108776739408', 'val': {'status': 'normal', 'response': 9581, 'timestamp': 1654108776.7438416}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108776748605', 'val': {'status': 'normal', 'response': 9222, 'timestamp': 1654108776.7549658}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108776763589', 'val': {'status': 'normal', 'response': 9224, 'timestamp': 1654108776.7719839}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108776780548', 'val': {'status': 'normal', 'response': 9225, 'timestamp': 1654108776.7890341}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108776796678', 'val': {'status': 'normal', 'response': 9226, 'timestamp': 1654108776.8027744}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108776812028', 'val': {'status': 'normal', 'response': 10232, 'timestamp': 1654108776.8162742}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108776819492', 'val': {'status': 'normal', 'response': 10234, 'timestamp': 1654108776.826899}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108776836442', 'val': {'status': 'normal', 'response': 10235, 'timestamp': 1654108776.8564475}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108776863811', 'val': {'status': 'normal', 'response': 10236, 'timestamp': 1654108776.8705342}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108776875613', 'val': {'status': 'normal', 'response': 9577, 'timestamp': 1654108776.8827126}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108776887909', 'val': {'status': 'normal', 'response': 9579, 'timestamp': 1654108776.8948019}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108776904025', 'val': {'status': 'normal', 'response': 9580, 'timestamp': 1654108776.9110594}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108776916040', 'val': {'status': 'normal', 'response': 9581, 'timestamp': 1654108776.922842}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108776931983', 'val': {'status': 'normal', 'response': 6492, 'timestamp': 1654108776.9390602}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108776943500', 'val': {'status': 'normal', 'response': 6494, 'timestamp': 1654108776.9476728}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108776951617', 'val': {'status': 'normal', 'response': 6495, 'timestamp': 1654108776.968329}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108776976350', 'val': {'status': 'normal', 'response': 6496, 'timestamp': 1654108776.9831557}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108776987831', 'val': {'status': 'normal', 'response': 7807, 'timestamp': 1654108776.994975}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777062207', 'val': {'status': 'normal', 'response': 7809, 'timestamp': 1654108777.0670362}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777080888', 'val': {'status': 'normal', 'response': 7810, 'timestamp': 1654108777.0867507}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777095705', 'val': {'status': 'normal', 'response': 7811, 'timestamp': 1654108777.1030343}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777107614', 'val': {'status': 'normal', 'response': 13436, 'timestamp': 1654108777.116383}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777120522', 'val': {'status': 'normal', 'response': 13438, 'timestamp': 1654108777.1665344}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777171293', 'val': {'status': 'normal', 'response': 13439, 'timestamp': 1654108777.1744745}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777177546', 'val': {'status': 'normal', 'response': 13440, 'timestamp': 1654108777.198588}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777203639', 'val': {'status': 'normal', 'response': 7692, 'timestamp': 1654108777.210874}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777215479', 'val': {'status': 'normal', 'response': 7694, 'timestamp': 1654108777.2229385}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777232515', 'val': {'status': 'normal', 'response': 7695, 'timestamp': 1654108777.243501}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777252180', 'val': {'status': 'normal', 'response': 7696, 'timestamp': 1654108777.2566578}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777259009', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.2756162}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777279903', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.2941701}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777308206', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.3222685}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777327098', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.3415263}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777346775', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.363981}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777367807', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.38097}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777383819', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.3964024}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777399528', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.4262798}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777429817', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.4465132}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777451774', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.4690523}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777473348', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.4886067}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777491903', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.5094671}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777513864', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.5398877}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777544072', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.5616488}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777567969', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.5817435}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777585165', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.602194}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777607385', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.623419}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777637288', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.653772}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777656834', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.6745937}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777676648', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.6940203}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777699670', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.7153661}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777719721', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.73368}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777748130', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.7628307}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777765841', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.7799904}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777782447', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.7978928}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777863244', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.8759816}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777878821', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.8908978}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777893163', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.9070282}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777908969', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.9244702}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777926883', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.9406323}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777943234', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.9569628}}
# DEBUG:Got command response
# DEBUG:Response: {'id': '1654108777959731', 'val': {'status': 'normal', 'response': None, 'timestamp': 1654108777.9729884}}

# %% [markdown]
# ### Inspect visibility data (need to copy it or run from lxdlwagpu09)

# %%
import subprocess

def read_mstar(filename):                                                         
    print(f"reading from {filename}")                                                                                                 
    try:
        if not os.path.exists(filename.rstrip('.tar')):
            cmd = f"tar xvf {filename}"
#            os.subprocess(cmd)
            p = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE, stderr=None)
            p.wait()
        tb = casacore.tables.table(filename.rstrip('.tar'))
#        os.system(f"tar cvf {filename} {filename.rstrip('.tar')}")
        return tb
    except RuntimeError:
        print(f"Could not open {filename}")
        return None

def get_data(tb, pol=0, label=None, show=True):
    if tb is None:
        return
    tb2 = tb.query('ANTENNA1=ANTENNA2')
    data = tb2.getcol("DATA").real
    times = tb2.getcol("TIME")
    print(data.shape, times.shape)
    if show:
        fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(12,5))
        im = ax0.imshow(data[..., 0].transpose(), origin='lower', interpolation='nearest', animated=True)
        im = ax1.imshow(data[..., 1].transpose(), origin='lower', interpolation='nearest', animated=True)
        ax0.set_xlabel('antenna')
        ax0.set_ylabel('channel')
        ax1.set_ylabel('channel')
        ax0.set_title(label + ', pol A')
        ax1.set_title(label + ', pol B')
    return data[..., pol].transpose()

# %%
filelist = sorted(glob.glob("/home/ubuntu/data/slow/20220601_18*24MHz.ms"))
print(len(filelist))
# Out:
# 75

# %%
writergif = animation.PillowWriter(fps=1)
fig, ax = plt.subplots(1, 1, figsize=(12,5))

def f(fn, pol=0):
    tb = read_mstar(fn)
    data = get_data(tb, pol=pol, show=False)
    return data

# ims is a list of lists, each row is a list of artists to draw in the
# current frame; here we are just animating one artist, the image, in
# each frame
ims = []
for fn in filelist:
    ax.set_xlabel('antenna')
    ax.set_ylabel('channel')
    ax.set_title(f"{os.path.basename(filelist[0])} to {os.path.basename(filelist[-1])}")
    data = ax.imshow(f(fn), animated=True)

    ims.append([data])

ani = animation.ArtistAnimation(fig, ims, interval=100, blit=True)

ani.save('tmp2.gif', writer=writergif)
# Out:
# reading from /home/ubuntu/data/slow/20220601_182634_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_182634_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_182644_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_182644_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_182654_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_182654_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_182704_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_182704_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_182714_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_182714_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_182724_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_182724_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_182734_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_182734_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_182745_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_182745_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_182755_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_182755_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_182805_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_182805_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_182815_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_182815_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_182825_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_182825_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_182835_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_182835_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_182845_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_182845_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_182855_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_182855_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_182905_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_182905_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_182915_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_182915_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_182925_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_182925_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_182935_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_182935_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_182945_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_182945_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_182955_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_182955_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183005_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183005_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183015_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183015_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183025_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183025_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183035_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183035_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183045_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183045_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183055_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183055_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183105_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183105_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183115_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183115_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183125_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183125_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183135_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183135_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183145_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183145_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183155_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183155_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183205_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183205_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183215_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183215_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183225_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183225_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183235_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183235_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183245_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183245_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183255_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183255_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183306_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183306_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183316_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183316_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183326_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183326_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183336_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183336_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183346_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183346_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183356_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183356_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183406_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183406_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183416_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183416_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183426_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183426_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183436_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183436_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183446_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183446_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183456_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183456_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183506_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183506_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183516_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183516_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183526_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183526_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183536_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183536_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183546_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183546_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183556_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183556_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183606_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183606_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183616_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183616_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183626_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183626_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183636_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183636_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183646_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183646_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183656_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183656_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183706_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183706_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183716_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183716_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183726_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183726_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183736_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183736_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183746_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183746_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183756_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183756_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183806_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183806_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183816_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183816_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183827_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183827_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183837_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183837_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183847_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183847_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# reading from /home/ubuntu/data/slow/20220601_183857_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183857_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)

# %%
Image('tmp2.gif')

# %%
fn = filelist[58]
print(fn)
tb = casacore.tables.table(fn)
tb2 = tb.query('ANTENNA1=ANTENNA2')
data = np.abs(tb2.getcol("DATA"))
times = tb2.getcol("TIME")
print(data.shape, times.shape)

fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(12,5))
im = ax0.imshow(data[..., 0].transpose(), origin='lower', interpolation='nearest', animated=True)
im = ax1.imshow(data[..., 1].transpose(), origin='lower', interpolation='nearest', animated=True)
ax0.set_xlabel('antenna')
ax0.set_ylabel('channel')
# Out:
# /home/ubuntu/data/slow/20220601_183616_24MHz.ms
# Successful readonly open of default-locked table /home/ubuntu/data/slow/20220601_183616_24MHz.ms: 22 columns, 62128 rows
# (352, 192, 4) (352,)
# Text(0,0.5,'channel')

# %%
mapping.correlator_to_antname(200)
# Out:
# 'LWA-112'
